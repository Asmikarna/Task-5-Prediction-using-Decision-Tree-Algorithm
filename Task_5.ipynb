# %% [markdown]
# **ASMI KARNA**
#
# **Prediction using Decision Tree Algorithm**
#
# ● Create the Decision Tree classifier and visualize it graphically.
#
# ● The purpose is if we feed any new data to this classifier, it would be able to
# predict the right class accordingly.

# %%
#importing Liabraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Extracting 
from sklearn.datasets import load_iris
#Decision Tree
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
class_count=3
plot_colors='brgs'
markers='ovs'
plot_res=0.01

# %%
iris=load_iris()

# %%
model=DecisionTreeClassifier().fit(iris.data,iris.target)

# %%
plt.figure(figsize=(20,20))
plot_tree(model,filled=True)
plt.show()

# %%
#Apply the decision tree classifier model to the data using all four parameters at once, but with a maximum tree depth of 3
model_all_params_max_depth_3=DecisionTreeClassifier(max_depth = 3).fit(iris.df,iris_target)
plt.figure(figsize=(16,10))
plot_tree(model_all_params_max_depth_3,
          rounded = True,
          filled=True     )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#     113         try:
# --> 114             return self[key]
#     115         except KeyError:
#
# KeyError: 'df'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-bcd8381eb378> in <module>()
#       1 #Apply the decision tree classifier model to the data using all four parameters at once, but with a maximum tree depth of 3
# ----> 2 model_all_params_max_depth_3=DecisionTreeClassifier(max_depth = 3).fit(iris.df,iris_target)
#       3 plt.figure(figsize=(16,10))
#       4 plot_tree(model_all_params_max_depth_3,
#       5           rounded = True,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#     114             return self[key]
#     115         except KeyError:
# --> 116             raise AttributeError(key)
#     117
#     118     def __setstate__(self, state):
#
# AttributeError: df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-ee7794e1-1c5e-4d15-9530-0fdc82881a75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee7794e1-1c5e-4d15-9530-0fdc82881a75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
# data imported 
import pandas as pd
import io

df=pd.read_csv(io.BytesIO(uploaded['Iris.csv']))

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail(4)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [4 rows x 6 columns]

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['PetalWidthCm'].plot.hist()

# %%
sns.pairplot(df,hue="Species")
plt.show()

# %%
for col in df.columns:
  print(col)
# Out:
# Id
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Species

# %%
x=df[['SepalLengthCm','SepalWidthCm','PetalWidthCm','PetalWidthCm']].values
y=df['Species'].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7, random_state=1)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (105, 4) (105,)
# (45, 4) (45,)

# %%
model= DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
acc=model.score(x_test,y_test)

# %%
print(" Accuracy:: ", acc)
# Out:
#  Accuracy::  0.9333333333333333

# %%
print("I got a good accuracy")
# Out:
# I got a good accuracy

# %% [markdown]
# **SUCCESSFULLY COMPLETED**
